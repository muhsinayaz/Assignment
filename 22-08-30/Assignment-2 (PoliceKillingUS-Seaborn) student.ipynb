# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %% [markdown]
# read data
#
# if didn't work you can use this parameters: encoding="windows-1252"

# %%
kill = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %%
kill.shape
# Out:
# (2535, 14)

# %%
kill.dropna(inplace=True)

# %%
kill.shape
# Out:
# (2254, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %%
kill.manner_of_death.unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
sns.boxplot(x="gender", y="age", hue="manner_of_death", data=kill)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='age'>

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
plt.figure(figsize=(10,6))
sns.swarmplot(x="gender", y="age", hue="manner_of_death", data=kill)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='age'>

# %%
# with seaborn

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
most_dang_city = kill.city.value_counts().head(12)
most_dang_city
# Out:
# Los Angeles     35
# Phoenix         28
# Houston         24
# Chicago         22
# Austin          18
# Las Vegas       17
# Columbus        16
# Miami           15
# San Antonio     15
# Indianapolis    14
# St. Louis       14
# Bakersfield     13
# Name: city, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.barplot(most_dang_city.index, most_dang_city.values,)
plt.xticks(rotation=45)
plt.title("Most Dangerous City", color="b", size=16)
# Out:
# Text(0.5, 1.0, 'Most Dangerous City')

# %%
test = {"armut": 25, "elma": 12, "muz": 5}

# %%
most_dang_city.to_frame()
# Out:
#               city
# Los Angeles     35
# Phoenix         28
# Houston         24
# Chicago         22
# Austin          18
# Las Vegas       17
# Columbus        16
# Miami           15
# San Antonio     15
# Indianapolis    14
# St. Louis       14
# Bakersfield     13

# %%
kill.groupby("city").count()
# Out:
#             id  name  date  manner_of_death  armed  age  gender  race  state  \
# city
# Abbeville    1     1     1                1      1    1       1     1      1
# Abilene      1     1     1                1      1    1       1     1      1
# Abingdon     1     1     1                1      1    1       1     1      1
# Acworth      1     1     1                1      1    1       1     1      1
# Addison      1     1     1                1      1    1       1     1      1
# ...         ..   ...   ...              ...    ...  ...     ...   ...    ...
# Yuba City    1     1     1                1      1    1       1     1      1
# Yulee        1     1     1                1      1    1       1     1      1
# Yuma         1     1     1                1      1    1       1     1      1
# Zanesville   1     1     1                1      1    1       1     1      1
# Zion         2     2     2                2      2    2       2     2      2
#
#             signs_of_mental_illness  threat_level  flee  body_camera
# city
# Abbeville                         1             1     1            1
# Abilene                           1             1     1            1
# Abingdon                          1             1     1            1
# Acworth                           1             1     1            1
# Addison                           1             1     1            1
# ...                             ...           ...   ...          ...
# Yuba City                         1             1     1            1
# Yulee                             1             1     1            1
# Yuma                              1             1     1            1
# Zanesville                        1             1     1            1
# Zion                              2             2     2            2
#
# [1282 rows x 13 columns]

# %%
plt.figure(figsize=(8,5))
sns.countplot(kill[most_dang_city.index])
plt.xticks(rotation=45)
plt.title("Most Dangerous City", color="b", size=16)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\mhsna\Desktop\Assigment\22-08-30\Assignment-2 (PoliceKillingUS-Seaborn) student.ipynb Hücre 26 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/mhsna/Desktop/Assigment/22-08-30/Assignment-2%20%28PoliceKillingUS-Seaborn%29%20student.ipynb#X61sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize=(8,5))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mhsna/Desktop/Assigment/22-08-30/Assignment-2%20%28PoliceKillingUS-Seaborn%29%20student.ipynb#X61sZmlsZQ%3D%3D?line=1'>2</a> sns.countplot(kill[most_dang_city.index])
#       <a href='vscode-notebook-cell:/c%3A/Users/mhsna/Desktop/Assigment/22-08-30/Assignment-2%20%28PoliceKillingUS-Seaborn%29%20student.ipynb#X61sZmlsZQ%3D%3D?line=2'>3</a> plt.xticks(rotation=45)
#       <a href='vscode-notebook-cell:/c%3A/Users/mhsna/Desktop/Assigment/22-08-30/Assignment-2%20%28PoliceKillingUS-Seaborn%29%20student.ipynb#X61sZmlsZQ%3D%3D?line=3'>4</a> plt.title("Most Dangerous City", color="b", size=16)
#
# File c:\Users\mhsna\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\mhsna\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File c:\Users\mhsna\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5842, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5840     if use_interval_msg:
#    5841         key = list(key)
# -> 5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Los Angeles', 'Phoenix', 'Houston', 'Chicago', 'Austin', 'Las Vegas',\n       'Columbus', 'Miami', 'San Antonio', 'Indianapolis', 'St. Louis',\n       'Bakersfield'],\n      dtype='object')] are in the [columns]"

# %%
# with seaborn countplot

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
most_dang_state= kill.state.value_counts().head(20)
most_dang_state
# Out:
# CA    366
# TX    200
# FL    136
# AZ    105
# OH     70
# NC     66
# OK     65
# CO     63
# GA     61
# MO     58
# TN     56
# IL     56
# WA     51
# LA     47
# AL     45
# PA     45
# NY     43
# VA     43
# WI     42
# NM     41
# Name: state, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=most_dang_state.index, y=most_dang_state.values)
plt.xticks(rotation=45)
plt.title("Most Dangerous States", color="b", size=16);

# %%
kill.state.value_counts().iloc[:10].index
# Out:
# Index(['CA', 'TX', 'FL', 'AZ', 'OH', 'NC', 'OK', 'CO', 'GA', 'MO'], dtype='object')

# %%
sns.countplot(kill.state)
plt.xlim()
# Out:
# (-0.5, 50.5)

# %%
# with seaborn countplot

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
kill.signs_of_mental_illness.value_counts()
# Out:
# False    1681
# True      573
# Name: signs_of_mental_illness, dtype: int64

# %%
sns.countplot(kill.signs_of_mental_illness)
# Out:
# <AxesSubplot:xlabel='signs_of_mental_illness', ylabel='count'>

# %%
# with seaborn

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
kill.threat_level.value_counts()
# Out:
# attack          1462
# other            677
# undetermined     115
# Name: threat_level, dtype: int64

# %%
sns.countplot(kill.threat_level)
# Out:
# <AxesSubplot:xlabel='threat_level', ylabel='count'>

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
kill.flee.value_counts()
# Out:
# Not fleeing    1528
# Car             360
# Foot            278
# Other            88
# Name: flee, dtype: int64

# %%
sns.countplot(kill.flee);
