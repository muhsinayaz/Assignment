# %% [markdown]
# # WITH PANDAS AND MATPLOTLIB

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
#
# 1. Number of people by gender
# 1. Kill weapon
# 1. Age of killed people
# 1. Race of killed people
# 1. Killed People According to Races (Pie Chart)
# 1. Most common 15 Name or Surname of killed people
#
# <br>

# %% [markdown]
# read data
#
# if didn't work you can use this parameters: encoding="windows-1252"

# %%
kill = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %% [markdown]
# ## 1: Plot number of people by gender

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill.gender.value_counts()
# Out:
# M    2428
# F     107
# Name: gender, dtype: int64

# %%
kill.groupby("gender")[["gender"]].count()
# Out:
#         gender
# gender
# F          107
# M         2428

# %%
plt.hist(x=kill.gender, bins=3)
# Out:
# (array([2428.,    0.,  107.]),
#  array([0.        , 0.33333333, 0.66666667, 1.        ]),
#  <BarContainer object of 3 artists>)

# %%
plt.hist(kill.groupby("gender")["gender"].count(), bins=3)
# Out:
# (array([1., 0., 1.]),
#  array([ 107.        ,  880.66666667, 1654.33333333, 2428.        ]),
#  <BarContainer object of 3 artists>)

# %%
kill.gender.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
kill.gender.value_counts()
# Out:
# M    2428
# F     107
# Name: gender, dtype: int64

# %%
plt.bar(x= ["m","f"], y=[2428, 107])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\mhsna\Desktop\Assigment\22-08-28\Assignment-1 (PoliceKillingUS-Matplotlib) student.ipynb Hücre 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mhsna/Desktop/Assigment/22-08-28/Assignment-1%20%28PoliceKillingUS-Matplotlib%29%20student.ipynb#Y121sZmlsZQ%3D%3D?line=0'>1</a> plt.bar(x= ["m","f"], y=[2428, 107])
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
# with matplotlib

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %% [markdown]
# ## 2: Plot 7 most common kill weapons

# %%
kill_armed_count = kill["armed"].value_counts().to_frame().head(8)
kill_armed_count
# Out:
#                 armed
# gun              1398
# knife             373
# vehicle           177
# unarmed           171
# undetermined      117
# toy weapon        104
# machete            18
# unknown weapon     18

# %%
kill_armed_index = kill_armed_count.index[:8]
kill_armed_index
# Out:
# Index(['gun', 'knife', 'vehicle', 'unarmed', 'undetermined', 'toy weapon',
#        'machete', 'unknown weapon'],
#       dtype='object')

# %%
plt.bar(kill_armed_index, kill_armed_count["armed"])
# for i, v in enumerate(kill_armed_count["armed"]):
#     plt.text(v-1 , i+1 , str(v))
plt.xticks(rotation = 45);

# %%
# with matplotlib

# %% [markdown]
# ## 3: Plot number of age of killed people under two groups : Under 25 and Above 25

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill["age_cat"] = np.nan

# %%
kill["age_cat"].loc[kill[kill["age"] > 25].index] = "above25"

# %%
kill["age_cat"].fillna("below25", inplace=True)  # filled the nan values ​​as below25 in the answer

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  age_cat
# 0  Not fleeing        False  above25
# ...

# %%
kill.age_cat.value_counts()
# Out:
# above25    1905
# below25     630
# Name: age_cat, dtype: int64

# %%
# with matplotlib

# %% [markdown]
# ## 4: Plot number of killed poeple by race

# %%
kill.race.value_counts()
# Out:
# W    1201
# B     618
# H     423
# A      39
# N      31
# O      28
# Name: race, dtype: int64

# %%
# with matplotlib

# %% [markdown]
# ## 5: Killed People According to Races (Pie Chart)

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  age_cat
# 0  Not fleeing        False  above25
# ...

# %%
# Out:
#    id                name      date  ...         flee body_camera  age_cat
# 0   3          Tim Elliot  02/01/15  ...  Not fleeing       False  above25
# 1   4    Lewis Lee Lembke  02/01/15  ...  Not fleeing       False  above25
# 2   5  John Paul Quintero  03/01/15  ...  Not fleeing       False  below25
# 3   8     Matthew Hoffman  04/01/15  ...  Not fleeing       False  above25
# 4   9   Michael Rodriguez  04/01/15  ...  Not fleeing       False  above25
#
# [5 rows x 15 columns]

# %%
kill.race.unique()
# Out:
# array(['A', 'W', 'H', 'B', 'O', nan, 'N'], dtype=object)

# %%
# Out:
# array(['A', 'W', 'H', 'B', 'O', nan, 'N'], dtype=object)

# %%
kill.race.value_counts(dropna=False)
# Out:
# W      1201
# B       618
# H       423
# NaN     195
# A        39
# N        31
# O        28
# Name: race, dtype: int64

# %%
# Out:
# W      1201
# B       618
# H       423
# NaN     195
# A        39
# N        31
# O        28
# Name: race, dtype: int64

# %% [markdown]
# Problem: missing value on race column.

# %% [markdown]
# **INSTRUCTION-1: Drop the all raws that contain missing value (dropna)**

# %%
kill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2535 entries, 0 to 2534
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       2535 non-null   int64
#  1   name                     2535 non-null   object
#  2   date                     2535 non-null   object
#  3   manner_of_death          2535 non-null   object
#  4   armed                    2526 non-null   object
#  5   age                      2458 non-null   float64
#  6   gender                   2535 non-null   object
#  7   race                     2340 non-null   object
#  8   city                     2535 non-null   object
#  9   state                    2535 non-null   object
#  10  signs_of_mental_illness  2535 non-null   bool
#  11  threat_level             2535 non-null   object
#  12  flee                     2470 non-null   object
#  13  body_camera              2535 non-null   bool
# ...

# %%
kill.dropna(inplace=True)

# %%
kill.shape
# Out:
# (2254, 15)

# %% [markdown]
# **INSTRUCTION-2: Demonstrate Race Ratio of Killed People by a Pie Chart (You can use Matplotlib)**

# %%
kill_race = kill.race.value_counts(dropna=False)
kill_race
# Out:
# W    1168
# B     592
# H     401
# A      36
# N      29
# O      28
# Name: race, dtype: int64

# %%
# Out:
# W    1168
# B     592
# H     401
# A      36
# N      29
# O      28
# Name: race, dtype: int64

# %%
kill_race.index
# Out:
# Index(['W', 'B', 'H', 'A', 'N', 'O'], dtype='object')

# %%
kill_race.values
# Out:
# array([1168,  592,  401,   36,   29,   28], dtype=int64)

# %%
# matplotlib
